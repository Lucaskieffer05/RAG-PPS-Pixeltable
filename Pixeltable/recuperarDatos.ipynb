# %%
import pixeltable as pxt

queries_data = pxt.get_table('rag_demo.queries')

queries_data.insert([{
    'id': 11,
    'question': '¿Qué son los métodos numéricos y cuál es su importancia en la mecánica computacional?',
    'answer': 'Los métodos numéricos son técnicas para resolver problemas matemáticos complejos mediante aproximaciones numéricas. Son fundamentales en la mecánica computacional para resolver ecuaciones diferenciales que no tienen solución analítica.'
}])

queries_data.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)   3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)    447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     896 self.starttime = time.time()
# --> 897 self.dbapi_connection = connection = pool._invoke_creator(self)
#     898 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\psycopg\connection.py:117, in Connection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#     116     assert last_ex
# --> 117     raise last_ex.with_traceback(None)
#     119 rv._autocommit = bool(autocommit)
#
# OperationalError: connection failed: connection to server at "127.0.0.1", port 57001 failed: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pixeltable as pxt
# ----> 3 queries_data = pxt.get_table('rag_demo.queries')
#       5 queries_data.insert([{
#       6     'id': 11,
#       7     'question': '¿Qué son los métodos numéricos y cuál es su importancia en la mecánica computacional?',
#       8     'answer': 'Los métodos numéricos son técnicas para resolver problemas matemáticos complejos mediante aproximaciones numéricas. Son fundamentales en la mecánica computacional para resolver ecuaciones diferenciales que no tienen solución analítica.'
#       9 }])
#      11 queries_data.head()
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\pixeltable\globals.py:349, in get_table(path)
#     324 """Get a handle to an existing table, view, or snapshot.
#     325
#     326 Args:
#    (...)    346     >>> tbl = pxt.get_table('my_snapshot')
#     347 """
#     348 path_obj = catalog.Path(path)
# --> 349 return Catalog.get().get_table(path_obj)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\pixeltable\catalog\catalog.py:113, in Catalog.get(cls)
#     110 @classmethod
#     111 def get(cls) -> Catalog:
#     112     if cls._instance is None:
# --> 113         cls._instance = cls()
#     114     return cls._instance
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\pixeltable\catalog\catalog.py:124, in Catalog.__init__(self)
#     122 self._tbl_versions = {}
#     123 self._tbls = {}  # don't use a defaultdict here, it doesn't cooperate with the debugger
# --> 124 self._init_store()
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\pixeltable\catalog\catalog.py:761, in Catalog._init_store(self)
#     759 def _init_store(self) -> None:
#     760     """One-time initialization of the stored catalog. Idempotent."""
# --> 761     with Env.get().begin_xact():
#     762         session = Env.get().session
#     763         if session.query(sql.func.count(schema.Dir.id)).scalar() > 0:
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\pixeltable\env.py:88, in Env.get(cls)
#      85 @classmethod
#      86 def get(cls) -> Env:
#      87     if cls._instance is None:
# ---> 88         cls._init_env()
#      89     return cls._instance
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\pixeltable\env.py:96, in Env._init_env(cls, reinit_db)
#      94 cls.__initializing = True
#      95 env = Env()
# ---> 96 env._set_up(reinit_db=reinit_db)
#      97 env._upgrade_metadata()
#      98 cls._instance = env
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\pixeltable\env.py:374, in Env._set_up(self, echo, reinit_db)
#     371 if reinit_db and self._store_db_exists():
#     372     self._drop_store_db()
# --> 374 create_db = not self._store_db_exists()
#     376 if create_db:
#     377     self._logger.info(f'creating database at: {self.db_url}')
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\pixeltable\env.py:415, in Env._store_db_exists(self)
#     413 engine = sql.create_engine(db_url, future=True)
#     414 try:
# --> 415     with engine.begin() as conn:
#     416         stmt = f"SELECT COUNT(*) FROM pg_database WHERE datname = '{self._db_name}'"
#     417         result = conn.scalar(sql.text(stmt))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\base.py:3238, in Engine.begin(self)
#    3213 @contextlib.contextmanager
#    3214 def begin(self) -> Iterator[Connection]:
#    3215     """Return a context manager delivering a :class:`_engine.Connection`
#    3216     with a :class:`.Transaction` established.
#    3217
#    (...)   3236
#    3237     """  # noqa: E501
# -> 3238     with self.connect() as conn:
#    3239         with conn.begin():
#    3240             yield conn
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\base.py:3274, in Engine.connect(self)
#    3251 def connect(self) -> Connection:
#    3252     """Return a new :class:`_engine.Connection` object.
#    3253
#    3254     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3271
#    3272     """
# -> 3274     return self._connection_cls(self)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\base.py:2439, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2437 elif should_wrap:
#    2438     assert sqlalchemy_exception is not None
# -> 2439     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2440 else:
#    2441     assert exc_info[1] is not None
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3276 def raw_connection(self) -> PoolProxiedConnection:
#    3277     """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279     The returned object is a proxied version of the DBAPI
#    (...)   3296
#    3297     """
# -> 3298     return self.pool.connect()
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)    447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     711     rec = cast(_ConnectionRecord, pool._do_get())
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#     716     dbapi_connection = rec.get_connection()
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     673 self.__pool = pool
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     899     self.fresh = True
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#     903 else:
#     904     # in SQLAlchemy 1.4 the first_connect event is not used by
#     905     # the engine, so this will usually not be set
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     895 try:
#     896     self.starttime = time.time()
# --> 897     self.dbapi_connection = connection = pool._invoke_creator(self)
#     898     pool.logger.debug("Created new connection %r", connection)
#     899     self.fresh = True
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\sqlalchemy\engine\default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Users\Kieff\Desktop\Pixeltable\RAG-PPS-Pixeltable\env\Lib\site-packages\psycopg\connection.py:117, in Connection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#     115 if not rv:
#     116     assert last_ex
# --> 117     raise last_ex.with_traceback(None)
#     119 rv._autocommit = bool(autocommit)
#     120 if row_factory:
#
# OperationalError: (psycopg.OperationalError) connection failed: connection to server at "127.0.0.1", port 57001 failed: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
